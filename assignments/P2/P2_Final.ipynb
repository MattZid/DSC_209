# %%
#!pip install scipy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# %%
#inflation annual percentage
df_cpi = pd.read_csv("WB CPI/API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_23195.csv",skiprows=2,header = 1)

#inequality gini index
df_gini = pd.read_csv("WB Gini Index/API_SI.POV.GINI_DS2_en_csv_v2_25089.csv",skiprows=2,header = 1)

#net migration
df_mig = pd.read_csv("WB Net Migration/API_SM.POP.NETM_DS2_en_csv_v2_97.csv",skiprows=2,header = 1)

#poverty headcount ratio at $3 a day (% of population)
df_pov = pd.read_csv("WB Poverty/API_SI.POV.DDAY_DS2_en_csv_v2_1716.csv",skiprows=2,header = 1)

#GDP
df_gdp = pd.read_csv("WB GDP/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_25118.csv",skiprows=2,header = 1)   

#Homicide rate per 100,000 people
df_hom = pd.read_csv("WB Homicide Rate/API_VC.IHR.PSRC.P5_DS2_en_csv_v2_6913.csv",skiprows=2,header = 1)  

#social metrics
df_soc = pd.read_csv("WB Social/social-development.csv",skiprows=0,header = 0)

#public metrics
df_pub = pd.read_csv("WB Public/public-sector-raw-2021.csv",skiprows=3,header = 0)

# %%
df_soc_usa = df_soc[df_soc['Country Name'] == 'United States']
df_pub_usa = df_pub[df_pub['Country Name'] == 'United States']

# %%
df_soc_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 145 to 14865
# Data columns (total 37 columns):
#  #   Column                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                           --------------  -----
#  0   Country Name                                                                                                     61 non-null     object
#  1   Country Code                                                                                                     61 non-null     object
#  2   Year                                                                                                             61 non-null     int64
#  3   average_value_Adolescent fertility rate (births per 1,000 women ages 15-19)                                      60 non-null     float64
#  4   average_value_Children in employment, female (% of female children ages 7-14)                                    0 non-null      float64
#  5   average_value_Children in employment, male (% of male children ages 7-14)                                        0 non-null      float64
#  6   average_value_Children in employment, study and work (% of children in employment, ages 7-14)                    0 non-null      float64
#  7   average_value_Children in employment, study and work, female (% of female children in employment, ages 7-14)     0 non-null      float64
#  8   average_value_Children in employment, study and work, male (% of male children in employment, ages 7-14)         0 non-null      float64
#  9   average_value_Children in employment, total (% of children ages 7-14)                                            0 non-null      float64
#  10  average_value_Children in employment, work only (% of children in employment, ages 7-14)                         0 non-null      float64
#  11  average_value_Children in employment, work only, female (% of female children in employment, ages 7-14)          0 non-null      float64
#  12  average_value_Children in employment, work only, male (% of male children in employment, ages 7-14)              0 non-null      float64
#  13  average_value_Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)                   30 non-null     float64
#  14  average_value_Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)                     30 non-null     float64
#  15  average_value_Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)                    30 non-null     float64
#  16  average_value_Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)    30 non-null     float64
#  17  average_value_Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)  30 non-null     float64
#  18  average_value_Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)        30 non-null     float64
#  19  average_value_Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)      30 non-null     float64
#  20  average_value_Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)    30 non-null     float64
#  21  average_value_Life expectancy at birth, female (years)                                                           60 non-null     float64
#  22  average_value_Life expectancy at birth, male (years)                                                             60 non-null     float64
#  23  average_value_Literacy rate, youth (ages 15-24), gender parity index (GPI)                                       0 non-null      float64
#  24  average_value_Prevalence of HIV, female (% ages 15-24)                                                           10 non-null     float64
#  25  average_value_Prevalence of HIV, male (% ages 15-24)                                                             10 non-null     float64
#  26  average_value_Proportion of seats held by women in national parliaments (%)                                      23 non-null     float64
#  27  average_value_Refugee population by country or territory of asylum                                               61 non-null     float64
#  28  average_value_Refugee population by country or territory of origin                                               30 non-null     float64
#  29  average_value_School enrollment, primary (gross), gender parity index (GPI)                                      34 non-null     float64
#  30  average_value_School enrollment, primary and secondary (gross), gender parity index (GPI)                        33 non-null     float64
#  31  average_value_School enrollment, secondary (gross), gender parity index (GPI)                                    35 non-null     float64
#  32  average_value_School enrollment, tertiary (gross), gender parity index (GPI)                                     46 non-null     float64
#  33  average_value_Unemployment, female (% of female labor force) (modeled ILO estimate)                              29 non-null     float64
#  34  average_value_Unemployment, male (% of male labor force) (modeled ILO estimate)                                  29 non-null     float64
#  35  average_value_Vulnerable employment, female (% of female employment) (modeled ILO estimate)                      29 non-null     float64
#  36  average_value_Vulnerable employment, male (% of male employment) (modeled ILO estimate)                          29 non-null     float64
# dtypes: float64(34), int64(1), object(2)
# memory usage: 18.1+ KB

# %%
df_soc_usa = df_soc_usa.drop(['Country Name','Country Code'], axis=1).reset_index(drop=True)
df_soc_usa.sort_values(by='Year', inplace=True,ascending=True)
df_soc_usa.reset_index(drop=True, inplace=True)

# %%
df_pub_usa = df_pub_usa.transpose().reset_index()
df_pub_usa.rename(columns={'index': 'Year'}, inplace=True)
df_pub_usa = df_pub_usa.drop([0,1,3]).reset_index(drop=True)
df_pub_usa.iloc[0,0] = "Year"
df_pub_usa.columns = df_pub_usa.iloc[0]
df_pub_usa = df_pub_usa.drop(0).reset_index(drop=True)
df_pub_usa = df_pub_usa.iloc[:-1]
df_pub_usa['Year'] = pd.to_numeric(df_pub_usa['Year'], errors='coerce').astype('Int64')
df_pub_usa
# Out:
# 0   Year Intentional homicides (per 100,000 people)  \
# 0   1960                                        NaN
# 1   1961                                        NaN
# 2   1962                                        NaN
# 3   1963                                        NaN
# 4   1964                                        NaN
# ..   ...                                        ...
# 56  2016                                   5.390755
# 57  2017                                   5.316767
# 58  2018                                   4.956951
# 59  2019                                        NaN
# 60  2020                                        NaN
#
# 0  Intentional homicides, male (per 100,000 male)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 56                                       8.570887
# 57                                       8.450629
# 58                                       7.757731
# 59                                            NaN
# 60                                            NaN
#
# 0  Intentional homicides, female (per 100,000 female)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                           2.277249
# 57                                           2.247834
# 58                                           2.213828
# 59                                                NaN
# 60                                                NaN
#
# 0  Internally displaced persons, total displaced by conflict and violence (number of people)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
# 0  Internally displaced persons, new displacement associated with disasters (number of cases)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                          1107000.0
# 57                                          1686000.0
# 58                                          1247000.0
# 59                                           916000.0
# 60                                          1714000.0
#
# 0  Internally displaced persons, new displacement associated with conflict and violence (number of cases)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
# 0  Battle-related deaths (number of people)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 56                                      NaN
# 57                                      NaN
# 58                                      NaN
# 59                                      NaN
# 60                                      NaN
#
# 0  Proportion of seats held by women in national parliaments (%)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                          19.168591
# 57                                          19.354839
# 58                                          23.502304
# 59                                          23.433875
# 60                                          27.464789
#
# 0  Arms exports (SIPRI trend indicator values)  ...  \
# 0                                 6001000000.0  ...
# 1                                 6301000000.0  ...
# 2                                 6104000000.0  ...
# 3                                 9351000000.0  ...
# 4                                12312000000.0  ...
# ..                                         ...  ...
# 56                                9868000000.0  ...
# 57                               12070000000.0  ...
# 58                                9895000000.0  ...
# 59                               10788000000.0  ...
# 60                                9372000000.0  ...
#
# 0  Net lending (+) / net borrowing (-) (% of GDP)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 56                                      -3.825058
# 57                                      -2.762889
# 58                                      -4.854381
# 59                                      -5.306615
# 60                                     -15.530495
#
# 0  Net lending (+) / net borrowing (-) (current LCU)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 56                                   -717010100000.0
# 57                                   -539950800000.0
# 58                                  -1000578200000.0
# 59                                  -1137378700000.0
# 60                                  -3251557600000.0
#
# 0  Net investment in nonfinancial assets (% of GDP)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 56                                          1.32605
# 57                                              NaN
# 58                                              NaN
# 59                                              NaN
# 60                                              NaN
#
# 0  Net investment in nonfinancial assets (current LCU)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                     248569000000.0
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
#
# 0  Net incurrence of liabilities, total (% of GDP)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 56                                        4.707755
# 57                                        3.247542
# 58                                        6.285736
# 59                                        5.560707
# 60                                       23.457678
#
# 0  Net incurrence of liabilities, total (current LCU)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 56                                     882472200000.0
# 57                                     634666400000.0
# 58                                    1295607100000.0
# 59                                    1191838800000.0
# 60                                    4911240300000.0
#
# 0  Central government debt, total (% of GDP)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 56                                 98.816982
# 57                                       NaN
# 58                                       NaN
# 59                                       NaN
# 60                                       NaN
#
# 0  Central government debt, total (current LCU)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 56                             18523318000000.0
# 57                                          NaN
# 58                                          NaN
# 59                                          NaN
# 60                                          NaN
#
# 0  Net acquisition of financial assets (% of GDP)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 56                                       1.100767
# 57                                       0.795821
# 58                                       1.567015
# 59                                       0.392787
# 60                                        8.10804
#
# 0  Net acquisition of financial assets (current LCU)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 56                                    206339600000.0
# 57                                    155527200000.0
# 58                                    322991000000.0
# 59                                     84187000000.0
# 60                                   1697547800000.0
#
# [61 rows x 108 columns]

# %%
df_pub_usa = df_pub_usa[['Year','Intentional homicides (per 100,000 people)','Central government debt, total (% of GDP)']]

# %%
list_of_data = [df_cpi, df_gini, df_mig, df_pov, df_gdp, df_hom]
list_of_data_names = ['CPI','Gini','Migration','Poverty','GDP', 'Homicide Rate']
list_of_us_data = []

# %%
for df in list_of_data:
    df = df[df['Country Name'] == 'United States']
    df = df.T
    df.drop(df.index[0:4], inplace=True)
    df = df.rename_axis('Year').reset_index()
    df['Year'] = pd.to_numeric(df['Year'], errors='coerce').astype('Int64')
    list_of_us_data.append(df)
for i in range(len(list_of_us_data)):
    list_of_us_data[i].rename(columns={list_of_us_data[i].columns[1]:list_of_data_names[i]}, inplace=True)
    print(list_of_us_data[i].head(5))
# Out:
#    Year       CPI
# 0  1960  1.457976
# 1  1961  1.070724
# 2  1962  1.198773
# 3  1963  1.239669
# 4  1964  1.278912
#    Year  Gini
# 0  1960   NaN
# 1  1961   NaN
# 2  1962   NaN
# 3  1963  36.7
# 4  1964  37.4
#    Year Migration
# 0  1960  422708.0
# 1  1961  580333.0
# 2  1962  625617.0
# 3  1963  639495.0
# 4  1964  618635.0
#    Year Poverty
# 0  1960     NaN
# 1  1961     NaN
# 2  1962     NaN
# 3  1963     1.5
# 4  1964     1.5
#    Year                  GDP
# 0  1960  542390475099.325989
# 1  1961  562640778342.418945
# 2  1962  604729643906.495972
# 3  1963  638380883119.282959
# 4  1964  685631590686.500977
#    Year Homicide Rate
# 0  1960           NaN
# 1  1961           NaN
# 2  1962           NaN
# 3  1963           NaN
# 4  1964           NaN

# %%
list_of_us_data[0].rename(columns={list_of_us_data[0].columns[1]:'CPI'}, inplace=True)
df_usa = pd.merge(list_of_us_data[0], list_of_us_data[1], on='Year', how='outer')
df_usa = pd.merge(df_usa, list_of_us_data[2], on='Year', how='outer')
df_usa = pd.merge(df_usa, list_of_us_data[3], on='Year', how='outer')
df_usa = pd.merge(df_usa, list_of_us_data[4], on='Year', how='outer')
df_usa = pd.merge(df_usa, list_of_us_data[5], on='Year', how='outer')
df_usa = pd.merge(df_usa, df_pub_usa, on='Year', how='outer')
df_usa = pd.merge(df_usa, df_soc_usa, on='Year', how='outer')

df_usa.drop(65, axis = 0, inplace=True)
df_usa
# Out:
#     Year       CPI  Gini  Migration Poverty                  GDP  \
# 0   1960  1.457976   NaN   422708.0     NaN  542390475099.325989
# 1   1961  1.070724   NaN   580333.0     NaN  562640778342.418945
# 2   1962  1.198773   NaN   625617.0     NaN  604729643906.495972
# 3   1963  1.239669  36.7   639495.0     1.5  638380883119.282959
# 4   1964  1.278912  37.4   618635.0     1.5  685631590686.500977
# ..   ...       ...   ...        ...     ...                  ...
# 60  2020  1.233584  40.0   329769.0     0.5     21354105000000.0
# 61  2021  4.697859  39.7   674787.0     0.5     23681171000000.0
# 62  2022    8.0028  41.7  1319009.0     1.2     26006893000000.0
# 63  2023  4.116338  41.8  1322668.0     1.2     27720709000000.0
# 64  2024  2.949525   NaN  1286132.0     NaN     29184890000000.0
#
#    Homicide Rate Intentional homicides (per 100,000 people)  \
# 0            NaN                                        NaN
# 1            NaN                                        NaN
# 2            NaN                                        NaN
# 3            NaN                                        NaN
# 4            NaN                                        NaN
# ..           ...                                        ...
# 60      6.354656                                        NaN
# 61      6.779722                                        NaN
# 62      6.512674                                        NaN
# 63      5.763408                                        NaN
# 64           NaN                                        NaN
#
#    Central government debt, total (% of GDP)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 60                                       NaN
# 61                                       NaN
# 62                                       NaN
# 63                                       NaN
# 64                                       NaN
#
#     average_value_Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                             81.7410
# 1                                             79.1850
# 2                                             76.6290
# 3                                             74.6802
# 4                                             72.7314
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     ...  average_value_Refugee population by country or territory of asylum  \
# 0   ...                                           500000.0
# 1   ...                                           500000.0
# 2   ...                                           500000.0
# 3   ...                                           500000.0
# 4   ...                                           500000.0
# ..  ...                                                ...
# 60  ...                                           340881.0
# 61  ...                                                NaN
# 62  ...                                                NaN
# 63  ...                                                NaN
# 64  ...                                                NaN
#
#     average_value_Refugee population by country or territory of origin  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                              369.0
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_School enrollment, primary (gross), gender parity index (GPI)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_School enrollment, primary and secondary (gross), gender parity index (GPI)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_School enrollment, secondary (gross), gender parity index (GPI)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_School enrollment, tertiary (gross), gender parity index (GPI)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_Unemployment, male (% of male labor force) (modeled ILO estimate)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_Vulnerable employment, female (% of female employment) (modeled ILO estimate)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
#     average_value_Vulnerable employment, male (% of male employment) (modeled ILO estimate)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
#
# [65 rows x 43 columns]

# %%
df_usa.columns
# Out:
# Index(['Year', 'CPI', 'Gini', 'Migration', 'Poverty', 'GDP', 'Homicide Rate',
#        'Intentional homicides (per 100,000 people)',
#        'Central government debt, total (% of GDP)',
#        'average_value_Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'average_value_Children in employment, female (% of female children ages 7-14)',
#        'average_value_Children in employment, male (% of male children ages 7-14)',
#        'average_value_Children in employment, study and work (% of children in employment, ages 7-14)',
#        'average_value_Children in employment, study and work, female (% of female children in employment, ages 7-14)',
#        'average_value_Children in employment, study and work, male (% of male children in employment, ages 7-14)',
#        'average_value_Children in employment, total (% of children ages 7-14)',
#        'average_value_Children in employment, work only (% of children in employment, ages 7-14)',
#        'average_value_Children in employment, work only, female (% of female children in employment, ages 7-14)',
#        'average_value_Children in employment, work only, male (% of male children in employment, ages 7-14)',
#        'average_value_Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate)',
#        'average_value_Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate)',
#        'average_value_Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate)',
#        'average_value_Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
#        'average_value_Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)',
#        'average_value_Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)',
#        'average_value_Labor force participation rate, male (% of male population ages 15-64) (modeled ILO estimate)',
#        'average_value_Labor force participation rate, total (% of total population ages 15-64) (modeled ILO estimate)',
#        'average_value_Life expectancy at birth, female (years)',
#        'average_value_Life expectancy at birth, male (years)',
#        'average_value_Literacy rate, youth (ages 15-24), gender parity index (GPI)',
#        'average_value_Prevalence of HIV, female (% ages 15-24)',
#        'average_value_Prevalence of HIV, male (% ages 15-24)',
#        'average_value_Proportion of seats held by women in national parliaments (%)',
#        'average_value_Refugee population by country or territory of asylum',
#        'average_value_Refugee population by country or territory of origin',
#        'average_value_School enrollment, primary (gross), gender parity index (GPI)',
#        'average_value_School enrollment, primary and secondary (gross), gender parity index (GPI)',
#        'average_value_School enrollment, secondary (gross), gender parity index (GPI)',
#        'average_value_School enrollment, tertiary (gross), gender parity index (GPI)',
#        'average_value_Unemployment, female (% of female labor force) (modeled ILO estimate)',
#        'average_value_Unemployment, male (% of male labor force) (modeled ILO estimate)',
#        'average_value_Vulnerable employment, female (% of female employment) (modeled ILO estimate)',
#        'average_value_Vulnerable employment, male (% of male employment) (modeled ILO estimate)'],
#       dtype='object')

# %%
#truthful number 2

fig, ax1 = plt.subplots()

# Left axis (CPI)
ax1.plot(df_usa['Year'], df_usa['CPI'], color='#274690', label='CPI', linewidth=2)
ax1.set_ylabel('CPI - Annual % Change')
ax1.tick_params(axis='y')
ax1.ticklabel_format(style='plain', axis='y')  # no scientific notation

# Right axis (Migration)
ax2 = ax1.twinx()
ax2.plot(df_usa['Year'], df_usa['Migration'], color='#FF958C', label='Migration', linewidth=2)
ax2.set_ylabel('Migration')
ax2.tick_params(axis='y')
ax2.ticklabel_format(style='plain', axis='y')

# Shared X-axis
ax1.set_xlabel('Year')
plt.title('CPI vs Migration Over Time')

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.tight_layout()
plt.show()

# %%
x = 2
bar_width = 0.4

#misleading number 2

# Filter data
subset = df_usa[df_usa['Year'].isin([1970, 2020])]

# x positions for each year
x = np.arange(len(subset))  # [0, 1]
bar_width = 0.35

fig, ax1 = plt.subplots()

# Left axis (CPI)
b1 = ax1.bar(x - bar_width/2, subset['CPI'], width=bar_width, color='#274690', label='CPI')
ax1.set_ylabel('CPI - Annual % Change')
ax1.tick_params(axis='y')
ax1.ticklabel_format(style='plain', axis='y')  # disable sci notation
ax1.set_ylim(0, 8)  # limit y-axis to exaggerate differences

# Right axis (Migration)
ax2 = ax1.twinx()
b2 = ax2.bar(x + bar_width/2, subset['Migration'], width=bar_width, color='#FF958C', label='Migration')
ax2.set_ylabel('Migration')
ax2.tick_params(axis='y')
ax2.ticklabel_format(style='plain', axis='y')

# X-axis labels
plt.xticks(x, subset['Year'])
plt.xlabel('Year')

# Combine legends from both axes
bars = b1 + b2
labels = [b.get_label() for b in bars]

# Combine legends properly from both axes
ax1.legend(
    [b1, b2],                # use the bar containers themselves
    ['CPI', 'Migration'],    # custom labels
    loc='upper right'
)

plt.suptitle('Americans Pay the Price:  The Clear Trend of Inflation and Migration')
plt.title('US Data taken from 1970 and 2020', fontsize=11)

plt.tight_layout()
plt.show()
