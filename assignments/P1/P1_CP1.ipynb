# %%
pip

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('grocerydb.csv')

# %%
df.head(5)
# Out:
#                                                 name   store   category  \
# 0  Stonyfield Organic Whole Milk Strawberry Beet ...  Target  baby-food
# 1  Stonyfield Organic Whole Milk Pear Spinach Man...  Target  baby-food
# 2  Once Upon a Farm Organic Mama Blueberry Fruit ...  Target  baby-food
# 3  Once Upon a Farm Organic Strawberry Kids&#39; ...  Target  baby-food
# 4  Horizon Organic Growing Years Strawberry Kids&...  Target  baby-food
#
#               brand      FPro  FPro_class  price  price percal  \
# 0        Stonyfield  0.815250         3.0   5.29      0.043984
# 1        Stonyfield  0.815250         3.0   5.29      0.043984
# 2  Once Upon a Farm  0.583219         3.0   2.79      0.055973
# 3  Once Upon a Farm  0.451056         0.0   2.49      0.019213
# 4            DANNON  0.773519         3.0   4.99      0.017781
#
#    package_weight   Protein  Total Fat  Carbohydrate  Sugars, total  \
# 0        396.8930  5.050505   3.030303     12.121212       9.090909
# 1        396.8930  5.050505   3.030303     12.121212       9.090909
# 2         90.7184  1.098901   0.549451     13.186813       7.692308
# 3         90.7184  5.494505   7.692308     15.384615       8.791209
# 4        396.8930  3.030303   1.010101     14.141414       6.060606
#
#    Fiber, total dietary    Sodium  Cholesterol
# 0              0.000000  0.080808     0.010101
# 1              0.000000  0.080808     0.010101
# 2              2.197802  0.010989     0.000000
# 3              3.296703  0.000000     0.000000
# 4              2.020202  0.050505     0.005051

# %%
df[['Protein','Total Fat','Carbohydrate','Sugars, total','Sodium','Fiber, total dietary','Cholesterol']].iloc[0].sum()
# Out:
# 29.383838383

# %%
print(df.columns)
print()
print(df.info())
# Out:
# Index(['name', 'store', 'category', 'brand', 'FPro', 'FPro_class', 'price',
#        'price percal', 'package_weight', 'Protein', 'Total Fat',
#        'Carbohydrate', 'Sugars, total', 'Fiber, total dietary', 'Sodium',
#        'Cholesterol'],
#       dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26250 entries, 0 to 26249
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  26250 non-null  object
#  1   store                 26250 non-null  object
#  2   category              26250 non-null  object
#  3   brand                 26181 non-null  object
#  4   FPro                  26250 non-null  float64
#  5   FPro_class            26250 non-null  float64
#  6   price                 22220 non-null  float64
#  7   price percal          20780 non-null  float64
#  8   package_weight        24975 non-null  float64
#  9   Protein               26250 non-null  float64
#  10  Total Fat             26250 non-null  float64
#  11  Carbohydrate          26250 non-null  float64
#  12  Sugars, total         26241 non-null  float64
#  13  Fiber, total dietary  26241 non-null  float64
#  14  Sodium                26250 non-null  float64
#  15  Cholesterol           26250 non-null  float64
# dtypes: float64(12), object(4)
# memory usage: 3.2+ MB
# None

# %%
df_cats  = df.groupby(by='category')[['price','Protein','Total Fat','Carbohydrate','Sugars, total','Sodium','Fiber, total dietary','Cholesterol']].mean()

# %%
df_cats_size = df.groupby(by='category')[['Protein','Total Fat','Carbohydrate','Sugars, total','Sodium','Fiber, total dietary','Cholesterol']].size()
print(df_cats_size.sort_values(ascending=False))
# Out:
# category
# prepared-meals-dishes      2043
# pastry-chocolate-candy     1529
# snacks-bars                1402
# cookies-biscuit            1228
# snacks-mixes-crackers      1116
# produce-packaged           1107
# produce-beans-wf           1071
# cheese                     1011
# snacks-chips                978
# ice-cream-dessert           907
# meat-packaged               898
# dairy-yogurt-drink          831
# cereal                      800
# bread                       689
# sauce-all                   662
# rolls-buns-wraps            659
# soup-stew                   622
# dressings                   574
# sausage-bacon               466
# snacks-dips-salsa           453
# cakes                       404
# milk-milk-substitute        402
# drink-juice                 391
# baking                      382
# seafood                     372
# pizza                       372
# snacks-nuts-seeds           357
# drink-shakes-other          309
# spread-squeeze              301
# breakfast                   289
# meat-poultry-wf             274
# muffins-bagels              253
# pasta-noodles               253
# jerky                       238
# spices-seasoning            232
# drink-coffee                223
# mac-cheese                  212
# snacks-popcorn              208
# culinary-ingredients        194
# nuts-seeds-wf               189
# pudding-jello               156
# drink-soft-energy-mixes     136
# salad                       135
# rice-grains-packaged        128
# coffee-beans-wf             126
# baby-food                   126
# drink-juice-wf              115
# eggs-wf                     110
# rice-grains-wf              110
# seafood-wf                   99
# drink-tea                    94
# drink-water-wf               14
# dtype: int64

# %%
df2 = pd.DataFrame(df_cats_size)

# %%
df2.rename(columns={0:'Count'},inplace=True)
df2.reset_index()
# Out:
#                    category  Count
# 0                 baby-food    126
# 1                    baking    382
# 2                     bread    689
# 3                 breakfast    289
# 4                     cakes    404
# 5                    cereal    800
# 6                    cheese   1011
# 7           coffee-beans-wf    126
# 8           cookies-biscuit   1228
# 9      culinary-ingredients    194
# 10       dairy-yogurt-drink    831
# 11                dressings    574
# 12             drink-coffee    223
# 13              drink-juice    391
# 14           drink-juice-wf    115
# 15       drink-shakes-other    309
# 16  drink-soft-energy-mixes    136
# 17                drink-tea     94
# 18           drink-water-wf     14
# 19                  eggs-wf    110
# 20        ice-cream-dessert    907
# 21                    jerky    238
# 22               mac-cheese    212
# 23            meat-packaged    898
# 24          meat-poultry-wf    274
# 25     milk-milk-substitute    402
# 26           muffins-bagels    253
# 27            nuts-seeds-wf    189
# 28            pasta-noodles    253
# 29   pastry-chocolate-candy   1529
# 30                    pizza    372
# 31    prepared-meals-dishes   2043
# 32         produce-beans-wf   1071
# 33         produce-packaged   1107
# 34            pudding-jello    156
# 35     rice-grains-packaged    128
# 36           rice-grains-wf    110
# 37         rolls-buns-wraps    659
# 38                    salad    135
# 39                sauce-all    662
# 40            sausage-bacon    466
# 41                  seafood    372
# 42               seafood-wf     99
# 43              snacks-bars   1402
# 44             snacks-chips    978
# 45        snacks-dips-salsa    453
# 46    snacks-mixes-crackers   1116
# 47        snacks-nuts-seeds    357
# 48           snacks-popcorn    208
# 49                soup-stew    622
# 50         spices-seasoning    232
# 51           spread-squeeze    301

# %%
df_cats.sort_values(by='Sugars, total',ascending = False, inplace = True)
print(df_cats.head(10))
# Out:
#                            price    Protein  Total Fat  Carbohydrate  \
# category
# pastry-chocolate-candy  4.036599   5.968492  24.428236     59.360412
# cookies-biscuit         3.891454   5.413935  19.407403     61.675685
# cakes                   5.601062   3.812273  17.926579     49.180493
# pudding-jello           2.925643   2.790213   5.107701     31.547147
# culinary-ingredients    4.913174   1.073606  35.761145     30.588448
# snacks-bars             7.764474  16.242717  18.523540     51.709138
# baking                  4.203786   8.441010  12.971675    116.000347
# spread-squeeze          6.162922  13.079643  33.369001     33.813918
# ice-cream-dessert       4.429986   3.404550  12.872844     32.914520
# cereal                  4.348554  10.245519   9.065059     72.634049
#
#                         Sugars, total    Sodium  Fiber, total dietary  \
# category
# pastry-chocolate-candy      39.490070  0.166450              4.777536
# cookies-biscuit             30.648365  0.316701              2.897132
# cakes                       30.246503  0.270955              1.274450
# pudding-jello               23.536853  0.245547              0.665561
# culinary-ingredients        23.367114  2.401752              1.213294
# snacks-bars                 22.557986  0.481686              8.678395
# baking                      22.231611  0.550055              6.089190
# spread-squeeze              21.235564  0.197900              5.088807
# ice-cream-dessert           20.741669  0.235821              1.255056
# cereal                      19.697981  0.419295              7.765913
#
#                         Cholesterol
# category
# pastry-chocolate-candy     0.019492
# cookies-biscuit            0.018121
# cakes                      0.033964
# pudding-jello              0.018200
# culinary-ingredients       0.039714
# snacks-bars                0.004955
# baking                     0.004620
# spread-squeeze             0.003394
# ice-cream-dessert          0.228282
# cereal                     0.002003

# %%
df_cats = df_cats.merge(df2,left_on='category',right_on='category',how='inner')

# %%
df_cats.reset_index(inplace=True)
df_cats.sort_values(by='Count',ascending=False,inplace=True,ignore_index=True)

# %%
df_cats
# Out:
#                    category      price    Protein  Total Fat  Carbohydrate  \
# 0     prepared-meals-dishes   4.944088   8.778541   7.714210     24.470031
# 1    pastry-chocolate-candy   4.036599   5.968492  24.428236     59.360412
# 2               snacks-bars   7.764474  16.242717  18.523540     51.709138
# 3           cookies-biscuit   3.891454   5.413935  19.407403     61.675685
# 4     snacks-mixes-crackers   3.634414   9.584123  16.541370     63.923872
# 5          produce-packaged   3.432184   2.737473   3.996584     19.520358
# 6          produce-beans-wf   3.573017   3.429117   0.787450     19.125045
# 7                    cheese   4.645843  19.350028  24.839163      4.627508
# 8              snacks-chips   3.386820   8.913645  27.303850     57.907110
# 9         ice-cream-dessert   4.429986   3.404550  12.872844     32.914520
# 10            meat-packaged   6.231209  17.111798  10.228266      7.710353
# 11       dairy-yogurt-drink   3.049814   5.487952   3.511088     11.988929
# 12                   cereal   4.348554  10.245519   9.065059     72.634049
# 13                    bread   3.891083   8.962654   4.861488     47.706177
# 14                sauce-all   3.726225   2.110541   5.826758     14.769635
# 15         rolls-buns-wraps   3.531463   8.671129   6.873899     49.177272
# 16                soup-stew   3.400175   5.847537   4.519125     21.710575
# 17                dressings   5.169367   1.740597  27.663215     15.436913
# 18            sausage-bacon   5.213960  19.128566  23.080503      4.116746
# 19        snacks-dips-salsa   3.927288   4.109383  11.767036     13.735908
# 20                    cakes   5.601062   3.812273  17.926579     49.180493
# 21     milk-milk-substitute   4.196320   3.142413   3.475987      7.215018
# 22              drink-juice   3.514787   0.797719   0.108672     13.261948
# 23                   baking   4.203786   8.441010  12.971675    116.000347
# 24                    pizza   5.814331  10.186227  11.800279     26.739666
# 25                  seafood   5.106918  17.381362   7.010220      5.011240
# 26        snacks-nuts-seeds   6.647258  16.623465  40.055319     33.787450
# 27       drink-shakes-other   9.193071   7.410301   2.833359     17.509844
# 28           spread-squeeze   6.162922  13.079643  33.369001     33.813918
# 29                breakfast   4.138605   9.480652  11.271993     37.220249
# 30          meat-poultry-wf   8.180550  19.632286  10.219040      0.465632
# 31            pasta-noodles   2.925470  12.298783   2.305220     66.113335
# 32           muffins-bagels   4.111256   7.660466   7.495652     50.768103
# 33                    jerky   6.040884  32.678943  12.810856     16.676500
# 34         spices-seasoning   3.578085   8.609721   7.367191     43.442902
# 35             drink-coffee   4.887427   2.660472   5.150849     19.721486
# 36               mac-cheese   3.661852   9.915512   7.229974     39.175571
# 37           snacks-popcorn   3.844521   8.069971  24.573159     57.459231
# 38     culinary-ingredients   4.913174   1.073606  35.761145     30.588448
# 39            nuts-seeds-wf   8.821402  15.013889  33.824242     36.945255
# 40            pudding-jello   2.925643   2.790213   5.107701     31.547147
# 41  drink-soft-energy-mixes   3.330420   1.797479   0.390613     17.337865
# 42                    salad   4.741739   6.658974  10.983728     14.321662
# 43     rice-grains-packaged   2.974444   6.342208   2.321069     45.494633
# 44          coffee-beans-wf  11.531304   0.232183   0.026881      1.421624
# 45                baby-food   2.447603   1.974136   1.432210     14.104166
# 46           drink-juice-wf   5.771529   0.675649   0.122060    187.689763
# 47                  eggs-wf   4.085125  11.051013   8.418699      1.835880
# 48           rice-grains-wf   6.256211   9.110198   1.389785     72.234375
# 49               seafood-wf  12.401139  19.527151   4.366358      0.393113
# 50                drink-tea   4.092647   1.481100   1.399039     19.900857
# 51           drink-water-wf   5.940000   0.000000   0.000000      0.000000
#
#     Sugars, total      Sodium  Fiber, total dietary  Cholesterol  Count
# 0        3.213817    0.418739              1.909048     0.022301   2043
# 1       39.490070    0.166450              4.777536     0.019492   1529
# 2       22.557986    0.481686              8.678395     0.004955   1402
# 3       30.648365    0.316701              2.897132     0.018121   1228
# 4       10.441529    0.702245              4.110957     0.007145   1116
# 5        9.037920    0.806048              2.941295     0.001428   1107
# 6        5.941667    8.445600              3.912010     0.000083   1071
# 7        1.560618    1.292371              0.214896     0.177476   1011
# 8        4.187794    0.643640              5.027450     0.004384    978
# 9       20.741669    0.235821              1.255056     0.228282    907
# 10       1.562333    0.702150              0.908947     0.046417    898
# 11       8.565553    0.106616              0.484040     0.010972    831
# 12      19.697981    0.419295              7.765913     0.002003    800
# 13       6.166848  795.235582              4.405692     0.005140    689
# 14       8.936493    0.665790              1.344793     0.005433    662
# 15       4.779970    0.491564              5.054549     0.004241    659
# 16       2.966171    0.945578              2.195617     0.005853    622
# 17       9.397055    0.872885              0.669143     0.008645    574
# 18       1.716231    1.023454              0.379592     0.070924    466
# 19       4.347724    0.654074              2.843271     0.008322    453
# 20      30.246503    0.270955              1.274450     0.033964    404
# 21       5.564204    0.065155              0.247159     0.008847    402
# 22       8.032298    0.045927              0.448751     0.000300    391
# 23      22.231611    0.550055              6.089190     0.004620    382
# 24       3.078631    0.516899              1.693614     0.023814    372
# 25       1.147118    2.031073              0.472844     0.152375    372
# 26      13.840529    0.349343              7.557058     0.004101    357
# 27      11.677840    0.225102              1.874744     0.004211    309
# 28      21.235564    0.197900              5.088807     0.003394    301
# 29       9.229165    0.498999              2.682603     0.042158    289
# 30       0.027788    0.131230              0.123679     0.077566    274
# 31       2.237041    0.113266              4.680917     0.011711    253
# 32      15.618872    0.402542              3.662205     0.014080    253
# 33      12.693076    1.493478              1.333350     0.085435    238
# 34       4.679200    3.542897             13.317722     0.000478    232
# 35      14.270014    0.141357              0.437346     0.004161    223
# 36       3.689917    0.578142              1.932874     0.016050    212
# 37       7.079351    0.648949              9.747714     0.003569    208
# 38      23.367114    2.401752              1.213294     0.039714    194
# 39      16.071967    0.233426             10.273158     0.000000    189
# 40      23.536853    0.245547              0.665561     0.018200    156
# 41       8.163042    0.174443              0.479950     0.001950    136
# 42       3.885160    0.340483              2.180923     0.025686    135
# 43       1.273539    0.409911              2.903388     0.000266    128
# 44       0.000000    0.002624              0.003307     0.000000    126
# 45       8.479105    0.024585              1.900506     0.002665    126
# 46       7.975294    0.011991              0.196921     0.000000    115
# 47       1.176276    0.133279              0.047937     0.316489    110
# 48       0.596803    0.013899              4.430910     0.000000    110
# 49       0.124706    1.316795              0.074671     0.064322     99
# 50      10.876732    0.044155              2.038826     0.002342     94
# 51       0.000000    0.000853              0.000000     0.000000     14

# %%
df['Protein_Price'] = df['price']/df['Protein']

# %%
top_20 = df_cats[['category','Count']].head(20)

# %%
top_20
# Out:
#                   category  Count
# 0    prepared-meals-dishes   2043
# 1   pastry-chocolate-candy   1529
# 2              snacks-bars   1402
# 3          cookies-biscuit   1228
# 4    snacks-mixes-crackers   1116
# 5         produce-packaged   1107
# 6         produce-beans-wf   1071
# 7                   cheese   1011
# 8             snacks-chips    978
# 9        ice-cream-dessert    907
# 10           meat-packaged    898
# 11      dairy-yogurt-drink    831
# 12                  cereal    800
# 13                   bread    689
# 14               sauce-all    662
# 15        rolls-buns-wraps    659
# 16               soup-stew    622
# 17               dressings    574
# 18           sausage-bacon    466
# 19       snacks-dips-salsa    453

# %%
plt.figure(figsize=(15, 6))
plt.bar(top_20['category'],top_20['Count'],width=.5)
#plt.axis([min(min(eps_1_dperc['quarter']),min(eps_2_dperc['quarter']))+pd.DateOffset(months=-1),max(max(eps_1_dperc['quarter']),max(eps_2_dperc['quarter']))+pd.DateOffset(months=1),y_min_perc-.1,y_max_perc+.1])
plt.xticks(rotation=90)
plt.xlabel("Category")
plt.ylabel("Count")
plt.title(f"Grocery Store Stock by Product Category")
plt.tight_layout()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26250 entries, 0 to 26249
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  26250 non-null  object
#  1   store                 26250 non-null  object
#  2   category              26250 non-null  object
#  3   brand                 26181 non-null  object
#  4   FPro                  26250 non-null  float64
#  5   FPro_class            26250 non-null  float64
#  6   price                 22220 non-null  float64
#  7   price percal          20780 non-null  float64
#  8   package_weight        24975 non-null  float64
#  9   Protein               26250 non-null  float64
#  10  Total Fat             26250 non-null  float64
#  11  Carbohydrate          26250 non-null  float64
#  12  Sugars, total         26241 non-null  float64
#  13  Fiber, total dietary  26241 non-null  float64
#  14  Sodium                26250 non-null  float64
#  15  Cholesterol           26250 non-null  float64
# dtypes: float64(12), object(4)
# memory usage: 3.2+ MB

# %%
plt.scatter(df_cats['price'],df_cats['Sugars, total'],sizes=df_cats['Count'])
plt.suptitle(f"Product Category, Average Price and Sugar Content")
plt.text(7,40,'Points are sized by count of items per category', fontsize=8)
plt.xlabel("Price")
plt.ylabel("Sugar Content")
# Out:
# Text(0, 0.5, 'Sugar Content')

# %%
Price_Mean = df['price'].mean()
Price_std = df['price'].std()

Q3_Price= df['price'].quantile(q=.75)
Q2_Price = df['price'].quantile(q=.25)

Price_Top = Price_Mean + 1.5*(Q3_Price)
Price_Bottom = Price_Mean - 1.5*(Q2_Price)

df_filt = df.loc[(df['price']>=Price_Bottom) & (df['price']<=Price_Top)]
#BGO_CSE_filt = BGO_CSE.loc[(BGO_CSE['SPEND']>=1)]

df_filt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21277 entries, 0 to 26249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  21277 non-null  object
#  1   store                 21277 non-null  object
#  2   category              21277 non-null  object
#  3   brand                 21227 non-null  object
#  4   FPro                  21277 non-null  float64
#  5   FPro_class            21277 non-null  float64
#  6   price                 21277 non-null  float64
#  7   price percal          19895 non-null  float64
#  8   package_weight        20200 non-null  float64
#  9   Protein               21277 non-null  float64
#  10  Total Fat             21277 non-null  float64
#  11  Carbohydrate          21277 non-null  float64
#  12  Sugars, total         21269 non-null  float64
#  13  Fiber, total dietary  21269 non-null  float64
#  14  Sodium                21277 non-null  float64
#  15  Cholesterol           21277 non-null  float64
#  16  Protein_Price         21277 non-null  float64
# dtypes: float64(13), object(4)
# memory usage: 2.9+ MB

# %%
protein_mean = df_filt['Protein'].mean()
protein_std = df_filt['Protein'].std()

Q3_Protein= df_filt['Protein'].quantile(q=.75)
Q2_Protein = df_filt['Protein'].quantile(q=.25)

Protein_Top = protein_mean + 1.5*(Q3_Protein)
Protein_Bottom = protein_mean - 1.5*(Q2_Protein)

df_filt = df_filt.loc[(df_filt['Protein']>=Protein_Bottom) & (df_filt['Protein']<=Protein_Top)]

# %%
protein_mean
# Out:
# 8.593887411583593

# %%
df_prep = df[df['category']=='prepared-meals-dishes']

# %%
protein_mean = df_prep['Cholesterol'].mean()
protein_std = df_prep['Protein'].std()

Q3_Protein= df_prep['Cholesterol'].quantile(q=.75)
Q2_Protein = df_prep['Cholesterol'].quantile(q=.25)

Protein_Top = protein_mean + 1.5*(Q3_Protein)
Protein_Bottom = protein_mean - 1.5*(Q2_Protein)

df_filt = df_prep.loc[(df_filt['Cholesterol']>=Protein_Bottom) & (df_prep['Cholesterol']<=Protein_Top)]

# %%
plt.scatter(df_filt['Protein'],df_filt['Cholesterol'])
plt.title(f"Prepared Meals-Dishes, Protein vs Cholesterol")
plt.xlabel("Protein")
plt.ylabel("Cholesterol")
# Out:
# Text(0, 0.5, 'Cholesterol')
